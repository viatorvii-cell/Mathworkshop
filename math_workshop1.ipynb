# %% [markdown]
# <a href="https://colab.research.google.com/github/viatorvii-cell/Mathworkshop/blob/main/math_workshop1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hrs = input("Enter hours: ")
h = float(hrs)
rate = input("Enter rate: ")
r = float(rate)
if hrs > 40:
  money = (40*r + (hrs-40)*r*1.5)
  print(money)
else:
  money = hrs*rate
  print(money)
# Out:
# Enter hours: 40
# Enter rate: 10.50
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_646/1153934702.py in <cell line: 0>()
#       3 rate = input("Enter rate: ")
#       4 r = float(rate)
# ----> 5 if hrs > 40:
#       6   money = (40*r + (hrs-40)*r*1.5)
#       7   print(money)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
def greetings(name):
  print("Welcome " + name)
greetings("Wonton")
# Out:
# Welcome Wonton

# %%
def area_of_triangle(b, h):
  return b*h/2
area = area_of_triangle(10, 5)
print(area)
# Out:
# 25.0

# %%
def order_number(num1, num2):
  if num2 > num1:

# %%
for l in
